# %%
# !pip install -q sentencepiece
# !pip install -q transformers
# !pip install -q pyspellchecker
# !pip install -q pyngrok
# !pip install -q gdown

# %%
from pyngrok import ngrok

# %%
# !ngrok config add-authtoken ''

# %%
import os

# %%
# !gdown --id 1ySdbUtnjJ9ouao061KV4_Rdyxo3H6WCu -O file.zip

# %%
# !unzip file.zip

# %%
os.rename('app (1)', 'app')
for root, dirs, files in os.walk('app'):
    for filename in files:
        old_path = os.path.join(root, filename)
        new_filename = f"{''.join(filename.split(' (1)'))}"
        new_path = os.path.join(root, new_filename)
        os.rename(old_path, new_path)
    for dirname in dirs:
        old_dir_path = os.path.join(root, dirname)
        new_dir_name = f"{dirname.split(' (1)')[0]}"
        new_dir_path = os.path.join(root, new_dir_name)
        os.rename(old_dir_path, new_dir_path)

for root, dirs, files in os.walk('app/templates'):
    for filename in files:
        old_path = os.path.join(root, filename)
        new_filename = f"{''.join(filename.split(' (1)'))}"
        new_path = os.path.join(root, new_filename)
        os.rename(old_path, new_path)
    for dirname in dirs:
        old_dir_path = os.path.join(root, dirname)
        new_dir_name = f"{dirname.split(' (1)')[0]}"
        new_dir_path = os.path.join(root, new_dir_name)
        os.rename(old_dir_path, new_dir_path)

# %%
# %run app/app.py
